# %%
# !git clone https://github.com/hoangducanh1865/car_license_plate_recognition_with_yolov8_and_easyocr.git

# %%
# !pip install numpy pandas matplotlib pillow opencv-python torch torchvision torchaudio tqdm pyyaml requests ultralytics easyocr filterpy scipy

# %%
# %cd car_license_plate_recognition_with_yolov8_and_easyocr

# %%
# !python -m src.main --max_frames 500 --use_kaggle 1
