# %%
# !git clone https://github.com/hoangducanh1865/license_plate_recognition.git
# Out:
# Cloning into 'license_plate_recognition'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 85 (delta 9), reused 81 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (85/85), 11.30 MiB | 38.06 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %cd license_plate_recognition
# Out:
# /kaggle/working/license_plate_recognition

# %%
# %pip install numpy pandas matplotlib pillow opencv-python torch torchvision torchaudio tqdm pyyaml requests ultralytics easyocr filterpy scipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 27.2 MB/s eta 0:00:0000:01
# ...
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110460 sha256=3b66391c49aa3f0bf99f91609d648d6aedfe470eee1afe92b577165cea8c285e
#   Stored in directory: /root/.cache/pip/wheels/77/bf/4c/b0c3f4798a0166668752312a67118b27a3cd341e13ac0ae6ee
# Successfully built filterpy
# ...

# %%
# !git reset --hard origin/main
# !git pull
# Out:
# HEAD is now at ba656df feat: update OCR logic to match with Vietnamese license plate rules
# Already up to date.

# %%
# !python -m src.main --use_kaggle 1
# Out:
# Using device: cuda
# Initializing components...
# Components initialized.
#
# Processing all video frames...
#
# 0: 384x640 1 person, 1 bicycle, 2 cars, 2 motorcycles, 61.0ms
# Speed: 3.3ms preprocess, 61.0ms inference, 20.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 2 cars, 2 motorcycles, 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 2 cars, 2 motorcycles, 6.1ms
# Speed: 2.4ms preprocess, 6.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 2 cars, 2 motorcycles, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 2 cars, 2 motorcycles, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 2 cars, 2 motorcycles, 5.9ms
# ...
